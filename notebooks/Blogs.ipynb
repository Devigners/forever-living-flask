# %%
import pandas as pd

df = pd.read_csv('static\\web-assets\\data\\blogs\\blogs.csv')

df['ID'] = list(range(14))
df.drop(13, inplace=True)
df.drop(['Post Type'], axis=1, inplace=True)
df.drop(['Author Username'], axis=1, inplace=True)
df.to_csv('static\\web-assets\\data\\blogs\\blogs_small.csv', index=False)

# %%
df = pd.read_csv('static\\web-assets\\data\\blogs\\blogs_small.csv')
urls = []
for i in range(1,df.shape[0]+1):
    url_str = "web-assets/images/aloe/"+ "{}".format(i) +".jpg"
    urls.append(url_str)
urls
# Out:
# ['web-assets/images/aloe/1.jpg',
#  'web-assets/images/aloe/2.jpg',
#  'web-assets/images/aloe/3.jpg',
#  'web-assets/images/aloe/4.jpg',
#  'web-assets/images/aloe/5.jpg',
#  'web-assets/images/aloe/6.jpg',
#  'web-assets/images/aloe/7.jpg',
#  'web-assets/images/aloe/8.jpg',
#  'web-assets/images/aloe/9.jpg',
#  'web-assets/images/aloe/10.jpg',
#  'web-assets/images/aloe/11.jpg',
#  'web-assets/images/aloe/12.jpg',
#  'web-assets/images/aloe/13.jpg']

# %%
df['Image'] = urls

# %%
df.to_csv('static\\web-assets\\data\\blogs\\blogs_small.csv', index=False)
df
# Out:
#     ID                                              Title  \
# 0    0                        Top 5 Benefits of Aloe vera
# 1    1                       Why do people use Aloe vera?
# 2    2      Forever Aloe Lips ingredients and their roles
# 3    3  Forever Bright Toothgel ingredients and their ...
# 4    4   Aloe Vera Gelly ingredients and their importance
# 5    5  Forever Aloe Vera Gel ingredients and their im...
# 6    6  Forever Aloe Lips ingredients and their import...
# 7    7  Forever Bright Toothgel ingredients and their ...
# 8    8  Forever Aloe Berry Nectar ingredients and impo...
# 9    9                    Aloe vera temperature tolerance
# 10  10              Does Aloe vera help with hair growth?
# 11  11                         Where does Aloe vera grow?
# 12  12                  Aloe vera juice for constipation!
#
#                                               Content              Date  \
# 0   There are <a href="https://joinnow.foreverlivi...  11/23/2022 19:16
# ...
