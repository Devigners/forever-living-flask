# %%
import pandas as pd

states = []

# %%
gb_city_df = pd.read_csv('countries_data\\World States Cities\\GB\\GB.csv')
gb_city_df
# Out:
#             city_ascii         country             admin_name  \
# 0            Middlebie  United Kingdom  Dumfries and Galloway
# 1            Bransgore  United Kingdom              Hampshire
# 2            Birthorpe  United Kingdom           Lincolnshire
# 3              Ashover  United Kingdom             Derbyshire
# 4       Llandeilor-Fan  United Kingdom                  Powys
# ...                ...             ...                    ...
# 14775       Mid Calder  United Kingdom     Edinburgh, City of
# 14776       Piddington  United Kingdom            Oxfordshire
# 14777        Torroboll  United Kingdom               Highland
# 14778  Kirk Merrington  United Kingdom                 Durham
# 14779          Boxford  United Kingdom         West Berkshire
#
#             admin_name_ascii         admin_type
# 0      Dumfries and Galloway       council area
# 1                  Hampshire             county
# 2               Lincolnshire             county
# 3                 Derbyshire             county
# 4                      Powys  unitary authority
# ...                      ...                ...
# 14775     Edinburgh, City of       council area
# 14776            Oxfordshire             county
# 14777               Highland       council area
# 14778                 Durham  unitary authority
# 14779         West Berkshire  unitary authority
#
# [14780 rows x 5 columns]

# %%
cities_county = gb_city_df[['city_ascii', 'admin_name']]

# %%
cities_county = cities_county.rename(columns = {'city_ascii':'city', 'admin_name': 'county'})

# %%
cities_county.drop_duplicates(inplace=True)
cities_county
# Out:
#                   city                 county
# 0            Middlebie  Dumfries and Galloway
# 1            Bransgore              Hampshire
# 2            Birthorpe           Lincolnshire
# 3              Ashover             Derbyshire
# 4       Llandeilor-Fan                  Powys
# ...                ...                    ...
# 14775       Mid Calder     Edinburgh, City of
# 14776       Piddington            Oxfordshire
# 14777        Torroboll               Highland
# 14778  Kirk Merrington                 Durham
# 14779          Boxford         West Berkshire
#
# [14699 rows x 2 columns]

# %%
cities_county.to_csv("countries_data\\World States Cities\\GB\\GB data.csv", index=False)
