# %%
import pandas as pd

states = []

# %%
us_city_df = pd.read_csv('countries_data\\World States Cities\\US\\US.csv')
us_city_df
# Out:
#               city_ascii        country      admin_name admin_name_ascii  \
# 0                Denmark  United States       Wisconsin        Wisconsin
# 1       Morningside Park  United States         Florida          Florida
# 2                Latimer  United States  South Carolina   South Carolina
# 3                De Soto  United States       Wisconsin        Wisconsin
# 4            Lanes Creek  United States  South Carolina   South Carolina
# ...                  ...            ...             ...              ...
# 107658     Pilibos Ranch  United States      California       California
# 107659         Griminger  United States      California       California
# 107660       Blaine Hill  United States    Pennsylvania     Pennsylvania
# 107661          Pennwood  United States        Delaware         Delaware
# 107662           Buckton  United States        New York         New York
#
#        admin_type
# 0           state
# 1           state
# 2           state
# 3           state
# 4           state
# ...           ...
# 107658      state
# 107659      state
# 107660      state
# 107661      state
# 107662      state
#
# [107663 rows x 5 columns]

# %%
states = states + us_city_df['admin_name'].to_list()

# %%
cities_states = us_city_df[['admin_name', 'city_ascii']]
cities_states
# Out:
#             admin_name        city_ascii
# 0            Wisconsin           Denmark
# 1              Florida  Morningside Park
# 2       South Carolina           Latimer
# 3            Wisconsin           De Soto
# 4       South Carolina       Lanes Creek
# ...                ...               ...
# 107658      California     Pilibos Ranch
# 107659      California         Griminger
# 107660    Pennsylvania       Blaine Hill
# 107661        Delaware          Pennwood
# 107662        New York           Buckton
#
# [107663 rows x 2 columns]

# %%
us_county_df = pd.read_csv('countries_data\\World States Cities\\USA counties\\uscounties.csv')
us_county_df.rename(columns = {'state_name':'state', 'county_ascii':'county'}, inplace = True)
us_county_df
# Out:
#         state       county
# 0     Alabama    Jefferson
# 1     Alabama       Mobile
# 2     Alabama      Madison
# 3     Alabama   Montgomery
# 4     Alabama      Baldwin
# ...       ...          ...
# 3138  Wyoming     Washakie
# 3139  Wyoming        Crook
# 3140  Wyoming       Weston
# 3141  Wyoming  Hot Springs
# 3142  Wyoming     Niobrara
#
# [3143 rows x 2 columns]

# %%
states = states + us_county_df['state'].to_list()

# %%
us_neighborhood_df = pd.read_csv('countries_data\\World States Cities\\USA neighborhoods\\usneighborhoods.csv')
us_neighborhood_df.rename(columns = {'state_name':'state', 'city_name':'city', 'neighborhood_ascii':'neighborhood'}, inplace = True)
us_neighborhood_df
# Out:
#                      state        city               neighborhood
# 0                  Georgia     Atlanta  Atlanta University Center
# 1                  Georgia     Atlanta               Hunter Hills
# 2                  Georgia     Atlanta                   Bankhead
# 3                  Georgia     Atlanta             English Avenue
# 4                  Georgia     Atlanta                 Adair Park
# ...                    ...         ...                        ...
# 3587               Georgia     Atlanta                   Buckhead
# 3588               Georgia     Atlanta              Blair Village
# 3589               Florida       Tampa                 West Tampa
# 3590  District of Columbia  Washington                Terra Cotta
# 3591               Florida       Miami                 Lemon City
#
# [3592 rows x 3 columns]

# %%
states = states + us_neighborhood_df['state'].to_list()

# %%
states = list(set(states))

# %%
us_df = pd.DataFrame(columns=['state', 'city', 'county', 'neighborhood'])

# %%
us_df['state'] = states

# %%
us_df = pd.concat([us_df, cities_states, us_county_df, us_neighborhood_df])

# %%
us_df.drop_duplicates(inplace=True)
us_df
# Out:
#                      state        city county   neighborhood admin_name  \
# 0                   Nevada         NaN    NaN            NaN        NaN
# 1                   Hawaii         NaN    NaN            NaN        NaN
# 2                 Nebraska         NaN    NaN            NaN        NaN
# 3                    Maine         NaN    NaN            NaN        NaN
# 4                 Kentucky         NaN    NaN            NaN        NaN
# ...                    ...         ...    ...            ...        ...
# 3587               Georgia     Atlanta    NaN       Buckhead        NaN
# 3588               Georgia     Atlanta    NaN  Blair Village        NaN
# 3589               Florida       Tampa    NaN     West Tampa        NaN
# 3590  District of Columbia  Washington    NaN    Terra Cotta        NaN
# 3591               Florida       Miami    NaN     Lemon City        NaN
#
#      city_ascii
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 3587        NaN
# 3588        NaN
# 3589        NaN
# 3590        NaN
# 3591        NaN
#
# [113946 rows x 6 columns]

# %%
us_df.to_csv("countries_data\\World States Cities\\US\\US data.csv", index=False)

# %%
us_df.columns
# Out:
# Index(['state', 'city', 'county', 'neighborhood', 'admin_name', 'city_ascii'], dtype='object')
